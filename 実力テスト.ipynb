# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(f'bank.csv')
df_test = pd.read_csv(f'bank_pred.csv')

# %%
df.head()
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0  55.0  self-employed  married   tertiary      no     1810     yes   no
# 1  54.0     management  married   tertiary      no      364     yes   no
# 2  35.0     technician  married  secondary      no     -180      no  yes
# 3  58.0        retired  married    primary      no       69      no   no
# 4  48.0     management  married   tertiary      no     2351      no   no
#
#    pdays  previous poutcome   result
# 0   -1.0         0  unknown     fail
# 1   -1.0         0  unknown     fail
# 2   -1.0         0  unknown  success
# 3   -1.0         0  unknown     fail
# 4  105.0         3  success  success

# %%
df_test.head()
# Out:
#    age          job   marital  education default  balance housing loan  pdays  \
# 0   53     services   married  secondary      no     1364      no   no     -1
# 1   36  blue-collar   married  secondary      no     1949     yes   no    319
# 2   40       admin.   married    unknown      no     3557     yes   no     -1
# 3   51   management  divorced  secondary      no     -175     yes  yes     -1
# 4   41   unemployed   married  secondary      no      277     yes   no    351
#
#    previous poutcome
# 0         0  unknown
# 1         3  failure
# 2         0  unknown
# 3         0  unknown
# 4         2  failure

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x=df['job'])
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x=df_test['job'])
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x=df_test['job'])
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        14965 non-null  float64
#  1   job        14992 non-null  object
#  2   marital    14955 non-null  object
#  3   education  15000 non-null  object
#  4   default    14938 non-null  object
#  5   balance    15000 non-null  int64
#  6   housing    14886 non-null  object
#  7   loan       14976 non-null  object
#  8   pdays      14921 non-null  float64
#  9   previous   15000 non-null  int64
#  10  poutcome   14848 non-null  object
#  11  result     15000 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# age           35
# job            8
# marital       45
# education      0
# default       62
# balance        0
# housing      114
# loan          24
# pdays         79
# previous       0
# poutcome     152
# result         0
# dtype: int64

# %%
df.shape
# Out:
# (15000, 12)

# %%
df['age'].mean()
# Out:
# 40.95770130304043

# %%
df['age'].median()
# Out:
# 39.0

# %%
df['balance'].mean()
# Out:
# 1359.1116

# %%
df['balance'].median()
# Out:
# 447.0

# %%
df['job'].mode()[0]
# Out:
# 'blue-collar'

# %%
df = df.fillna({'age': df['age'].mean()})

# %%
df.isnull().sum()
# Out:
# age            0
# job            8
# marital       45
# education      0
# default       62
# balance        0
# housing      114
# loan          24
# pdays         79
# previous       0
# poutcome     152
# result         0
# dtype: int64

# %%
plt.hist(df['age'])
# Out:
# (array([ 455., 3861., 4295., 2654., 2377., 1100.,  120.,  100.,   33.,
#            5.]),
#  array([18. , 25.7, 33.4, 41.1, 48.8, 56.5, 64.2, 71.9, 79.6, 87.3, 95. ]),
#  <BarContainer object of 10 artists>)

# %%
df = df.fillna({'job':df['job'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age            0
# job            0
# marital       45
# education      0
# default       62
# balance        0
# housing      114
# loan          24
# pdays         79
# previous       0
# poutcome     152
# result         0
# dtype: int64

# %%
sns.countplot(x=df['loan'])
# Out:
# <Axes: xlabel='loan', ylabel='count'>

# %%
df = df.fillna({'loan':df['loan'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age            0
# job            0
# marital       45
# education      0
# default       62
# balance        0
# housing      114
# loan           0
# pdays         79
# previous       0
# poutcome     152
# result         0
# dtype: int64

# %%
sns.countplot(x=df['marital'])
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
df = df.fillna({'marital':df['marital'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default       62
# balance        0
# housing      114
# loan           0
# pdays         79
# previous       0
# poutcome     152
# result         0
# dtype: int64

# %%
sns.countplot(x=df['poutcome'])
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %%
df = df.fillna({'poutcome':df['poutcome'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default       62
# balance        0
# housing      114
# loan           0
# pdays         79
# previous       0
# poutcome       0
# result         0
# dtype: int64

# %%
sns.countplot(x=df['housing'])
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
df = df.fillna({'housing':df['housing'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default      62
# balance       0
# housing       0
# loan          0
# pdays        79
# previous      0
# poutcome      0
# result        0
# dtype: int64

# %%
sns.countplot(x=df['default'])
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
df = df.fillna({'default':df['default'].mode()[0]})

# %%
df.isnull().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# pdays        79
# previous      0
# poutcome      0
# result        0
# dtype: int64

# %%
plt.hist(df['pdays'])
# Out:
# (array([1.2295e+04, 7.1500e+02, 7.2200e+02, 5.3500e+02, 5.9200e+02,
#         3.4000e+01, 1.3000e+01, 5.0000e+00, 4.0000e+00, 6.0000e+00]),
#  array([ -1. ,  82.9, 166.8, 250.7, 334.6, 418.5, 502.4, 586.3, 670.2,
#         754.1, 838. ]),
#  <BarContainer object of 10 artists>)

# %%
df['pdays'].median()
# Out:
# -1.0

# %%
df['pdays'].mean()
# Out:
# 41.122914013806046

# %%
df = df.fillna({'pdays': df['pdays'].median()})

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# result       0
# dtype: int64

# %%
df.head()
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0  55.0  self-employed  married   tertiary      no     1810     yes   no
# 1  54.0     management  married   tertiary      no      364     yes   no
# 2  35.0     technician  married  secondary      no     -180      no  yes
# 3  58.0        retired  married    primary      no       69      no   no
# 4  48.0     management  married   tertiary      no     2351      no   no
#
#    pdays  previous poutcome   result
# 0   -1.0         0  unknown     fail
# 1   -1.0         0  unknown     fail
# 2   -1.0         0  unknown  success
# 3   -1.0         0  unknown     fail
# 4  105.0         3  success  success

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df['default'])

le.transform(df['default'])

df['default'] = le.transform(df['default'])

df.head()
# Out:
#     age            job  marital  education  default  balance housing loan  \
# 0  55.0  self-employed  married   tertiary        0     1810     yes   no
# 1  54.0     management  married   tertiary        0      364     yes   no
# 2  35.0     technician  married  secondary        0     -180      no  yes
# 3  58.0        retired  married    primary        0       69      no   no
# 4  48.0     management  married   tertiary        0     2351      no   no
#
#    pdays  previous poutcome   result
# 0   -1.0         0  unknown     fail
# 1   -1.0         0  unknown     fail
# 2   -1.0         0  unknown  success
# 3   -1.0         0  unknown     fail
# 4  105.0         3  success  success

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df['result'])

le.transform(df['result'])

df['result'] = le.transform(df['result'])

df.head()
# Out:
#     age            job  marital  education  default  balance housing loan  \
# 0  55.0  self-employed  married   tertiary        0     1810     yes   no
# 1  54.0     management  married   tertiary        0      364     yes   no
# 2  35.0     technician  married  secondary        0     -180      no  yes
# 3  58.0        retired  married    primary        0       69      no   no
# 4  48.0     management  married   tertiary        0     2351      no   no
#
#    pdays  previous poutcome  result
# 0   -1.0         0  unknown       0
# 1   -1.0         0  unknown       0
# 2   -1.0         0  unknown       1
# 3   -1.0         0  unknown       0
# 4  105.0         3  success       1

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df['loan'])

le.transform(df['loan'])

df['loan'] = le.transform(df['loan'])

df.head()
# Out:
#     age            job  marital  education  default  balance housing  loan  \
# 0  55.0  self-employed  married   tertiary        0     1810     yes     0
# 1  54.0     management  married   tertiary        0      364     yes     0
# 2  35.0     technician  married  secondary        0     -180      no     1
# 3  58.0        retired  married    primary        0       69      no     0
# 4  48.0     management  married   tertiary        0     2351      no     0
#
#    pdays  previous poutcome  result
# 0   -1.0         0  unknown       0
# 1   -1.0         0  unknown       0
# 2   -1.0         0  unknown       1
# 3   -1.0         0  unknown       0
# 4  105.0         3  success       1

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df['housing'])

le.transform(df['housing'])

df['housing'] = le.transform(df['housing'])

df.head()
# Out:
#     age            job  marital  education  default  balance  housing  loan  \
# 0  55.0  self-employed  married   tertiary        0     1810        1     0
# 1  54.0     management  married   tertiary        0      364        1     0
# 2  35.0     technician  married  secondary        0     -180        0     1
# 3  58.0        retired  married    primary        0       69        0     0
# 4  48.0     management  married   tertiary        0     2351        0     0
#
#    pdays  previous poutcome  result
# 0   -1.0         0  unknown       0
# 1   -1.0         0  unknown       0
# 2   -1.0         0  unknown       1
# 3   -1.0         0  unknown       0
# 4  105.0         3  success       1

# %%
df = pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#     age  default  balance  housing  loan  pdays  previous  result  \
# 0  55.0        0     1810        1     0   -1.0         0       0
# 1  54.0        0      364        1     0   -1.0         0       0
# 2  35.0        0     -180        0     1   -1.0         0       1
# 3  58.0        0       69        0     0   -1.0         0       0
# 4  48.0        0     2351        0     0  105.0         3       1
#
#    job_blue-collar  job_entrepreneur  ...  job_unemployed  job_unknown  \
# 0            False             False  ...           False        False
# 1            False             False  ...           False        False
# 2            False             False  ...           False        False
# 3            False             False  ...           False        False
# 4            False             False  ...           False        False
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                False                True
# 1             True           False                False                True
# 2             True           False                 True               False
# 3             True           False                False               False
# 4             True           False                False                True
#
#    education_unknown  poutcome_other  poutcome_success  poutcome_unknown
# 0              False           False             False              True
# 1              False           False             False              True
# 2              False           False             False              True
# 3              False           False             False              True
# 4              False           False              True             False
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (15000, 27)

# %%
x_train = df.drop(['result'],axis=1)
x_train.head()
# Out:
#     age  default  balance  housing  loan  pdays  previous  job_blue-collar  \
# 0  55.0        0     1810        1     0   -1.0         0            False
# 1  54.0        0      364        1     0   -1.0         0            False
# 2  35.0        0     -180        0     1   -1.0         0            False
# 3  58.0        0       69        0     0   -1.0         0            False
# 4  48.0        0     2351        0     0  105.0         3            False
#
#    job_entrepreneur  job_housemaid  ...  job_unemployed  job_unknown  \
# 0             False          False  ...           False        False
# 1             False          False  ...           False        False
# 2             False          False  ...           False        False
# 3             False          False  ...           False        False
# 4             False          False  ...           False        False
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                False                True
# 1             True           False                False                True
# 2             True           False                 True               False
# 3             True           False                False               False
# 4             True           False                False                True
#
#    education_unknown  poutcome_other  poutcome_success  poutcome_unknown
# 0              False           False             False              True
# 1              False           False             False              True
# 2              False           False             False              True
# 3              False           False             False              True
# 4              False           False              True             False
#
# [5 rows x 26 columns]

# %%
y_train = df['result']
y_train.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: result, dtype: int32

# %%
plt.hist(df_test['age'])
# Out:
# (array([ 293., 2239., 2604., 1987., 1486., 1118.,  128.,   76.,   51.,
#           18.]),
#  array([18. , 25.1, 32.2, 39.3, 46.4, 53.5, 60.6, 67.7, 74.8, 81.9, 89. ]),
#  <BarContainer object of 10 artists>)

# %%
df_test['age'].mean()
# Out:
# 40.8562

# %%
df_test['age'].median()
# Out:
# 39.0

# %%
df_test = df_test.fillna({'age':df_test['age'].mean()})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
plt.hist(df_test['pdays'])
# Out:
# (array([8.235e+03, 5.010e+02, 4.950e+02, 3.480e+02, 3.650e+02, 2.700e+01,
#         1.300e+01, 6.000e+00, 4.000e+00, 6.000e+00]),
#  array([ -1. ,  83.3, 167.6, 251.9, 336.2, 420.5, 504.8, 589.1, 673.4,
#         757.7, 842. ]),
#  <BarContainer object of 10 artists>)

# %%
df_test['pdays'].mean()
# Out:
# 41.1572

# %%
df_test['pdays'].median()
# Out:
# -1.0

# %%
df_test = df_test.fillna({'pdays':df_test['pdays'].median()})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df_test['job'])
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
df_test['job'].mode()[0]
# Out:
# 'blue-collar'

# %%
df_test = df_test.fillna({'job':df_test['job'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test['marital'].mode()[0]
# Out:
# 'married'

# %%
df_test = df_test.fillna({'marital':df_test['marital'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test['default'].mode()[0]
# Out:
# 'no'

# %%
df_test = df_test.fillna({'default':df_test['default'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test['housing'].mode()[0]
# Out:
# 'yes'

# %%
df_test = df_test.fillna({'housing':df_test['housing'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test['loan'].mode()[0]
# Out:
# 'no'

# %%
df_test = df_test.fillna({'loan':df_test['loan'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test['poutcome'].mode()[0]
# Out:
# 'unknown'

# %%
df_test = df_test.fillna({'poutcome':df_test['poutcome'].mode()[0]})

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_test.head()
# Out:
#    age          job   marital  education default  balance housing loan  pdays  \
# 0   53     services   married  secondary      no     1364      no   no     -1
# 1   36  blue-collar   married  secondary      no     1949     yes   no    319
# 2   40       admin.   married    unknown      no     3557     yes   no     -1
# 3   51   management  divorced  secondary      no     -175     yes  yes     -1
# 4   41   unemployed   married  secondary      no      277     yes   no    351
#
#    previous poutcome
# 0         0  unknown
# 1         3  failure
# 2         0  unknown
# 3         0  unknown
# 4         2  failure

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df_test['default'])

le.transform(df_test['default'])

df_test['default'] = le.transform(df_test['default'])

df_test.head()
# Out:
#    age          job   marital  education  default  balance housing loan  \
# 0   53     services   married  secondary        0     1364      no   no
# 1   36  blue-collar   married  secondary        0     1949     yes   no
# 2   40       admin.   married    unknown        0     3557     yes   no
# 3   51   management  divorced  secondary        0     -175     yes  yes
# 4   41   unemployed   married  secondary        0      277     yes   no
#
#    pdays  previous poutcome
# 0     -1         0  unknown
# 1    319         3  failure
# 2     -1         0  unknown
# 3     -1         0  unknown
# 4    351         2  failure

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df_test['housing'])

le.transform(df_test['housing'])

df_test['housing'] = le.transform(df_test['housing'])

df_test.head()
# Out:
#    age          job   marital  education  default  balance  housing loan  \
# 0   53     services   married  secondary        0     1364        0   no
# 1   36  blue-collar   married  secondary        0     1949        1   no
# 2   40       admin.   married    unknown        0     3557        1   no
# 3   51   management  divorced  secondary        0     -175        1  yes
# 4   41   unemployed   married  secondary        0      277        1   no
#
#    pdays  previous poutcome
# 0     -1         0  unknown
# 1    319         3  failure
# 2     -1         0  unknown
# 3     -1         0  unknown
# 4    351         2  failure

# %%
#ラベルエンコーディング（各クラスに数値を割り振る）
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(df_test['loan'])

le.transform(df_test['loan'])

df_test['loan'] = le.transform(df_test['loan'])

df_test.head()
# Out:
#    age  default  balance  housing  loan  pdays  previous  job_blue-collar  \
# 0   53        0     1364        0     0     -1         0            False
# 1   36        0     1949        1     0    319         3             True
# 2   40        0     3557        1     0     -1         0            False
# 3   51        0     -175        1     1     -1         0            False
# 4   41        0      277        1     0    351         2            False
#
#    job_entrepreneur  job_housemaid  ...  job_unemployed  job_unknown  \
# 0             False          False  ...           False        False
# 1             False          False  ...           False        False
# 2             False          False  ...           False        False
# 3             False          False  ...           False        False
# 4             False          False  ...            True        False
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                 True               False
# 1             True           False                 True               False
# 2             True           False                False               False
# 3            False           False                 True               False
# 4             True           False                 True               False
#
#    education_unknown  poutcome_other  poutcome_success  poutcome_unknown
# 0              False           False             False              True
# 1              False           False             False             False
# 2               True           False             False              True
# 3              False           False             False              True
# 4              False           False             False             False
#
# [5 rows x 26 columns]

# %%
df_test = pd.get_dummies(df_test,drop_first=True)
df_test.head()
# Out:
#    age  default  balance  housing  loan  pdays  previous  job_blue-collar  \
# 0   53        0     1364        0     0     -1         0            False
# 1   36        0     1949        1     0    319         3             True
# 2   40        0     3557        1     0     -1         0            False
# 3   51        0     -175        1     1     -1         0            False
# 4   41        0      277        1     0    351         2            False
#
#    job_entrepreneur  job_housemaid  ...  job_unemployed  job_unknown  \
# 0             False          False  ...           False        False
# 1             False          False  ...           False        False
# 2             False          False  ...           False        False
# 3             False          False  ...           False        False
# 4             False          False  ...            True        False
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                 True               False
# 1             True           False                 True               False
# 2             True           False                False               False
# 3            False           False                 True               False
# 4             True           False                 True               False
#
#    education_unknown  poutcome_other  poutcome_success  poutcome_unknown
# 0              False           False             False              True
# 1              False           False             False             False
# 2               True           False             False              True
# 3              False           False             False              True
# 4              False           False             False             False
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=0)

# %%
x_train.shape
# Out:
# (10500, 26)

# %%
x_test.shape
# Out:
# (4500, 26)

# %%
y_train.shape
# Out:
# (10500,)

# %%
y_test.shape
# Out:
# (4500,)

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(random_state=0)
dtree.fit(x_train,y_train)

print('train score:',dtree.score(x_train,y_train))
print('test score:',dtree.score(x_test,y_test))
# Out:
# train score: 0.9992380952380953
# test score: 0.8124444444444444

# %%
y_dtree = dtree.predict(df_test)

# %%
#標準化
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()

std_scaler.fit(x_train,x_test)
# Out:
# StandardScaler()

# %%
x_train_std = std_scaler.transform(x_train)
x_test_std = std_scaler.transform(x_test)
x_pred_std = std_scaler.transform(df_test)

# %%
from sklearn.svm import SVC

svc = SVC()

svc.fit(x_train_std,y_train)

print('train score:',svc.score(x_train_std,y_train))
print('test score:',svc.score(x_test_std,y_test))
# Out:
# train score: 0.8983809523809524
# test score: 0.8844444444444445

# %%
y_svc = svc.predict(df_test)
# Out:
# c:\Users\81908\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(C=1.0)

log_reg.fit(x_train,y_train)

print('train score:',log_reg.score(x_train,y_train))
print('test score:',log_reg.score(x_test,y_test))
# Out:
# train score: 0.8916190476190476
# test score: 0.8804444444444445
# c:\Users\81908\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_log = dtree.predict(df_test)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=3,max_depth=2,random_state=0)

model.fit(x_train,y_train)

print('train score:',model.score(x_train,y_train))
print('test score:',model.score(x_test,y_test))
# Out:
# train score: 0.8936190476190476
# test score: 0.8833333333333333

# %%
y_rand = dtree.predict(df_test)

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(x_train,y_train)

print('train score:',model.score(x_train,y_train))
print('test score:',model.score(x_test,y_test))
# Out:
# train score: 0.9292380952380952
# test score: 0.8773333333333333

# %%
y_xgb = dtree.predict(df_test)

# %%
y_xgb
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_xgb.dtype
# Out:
# dtype('int32')

# %%
y_xgb = y_xgb.astype(object)
y_xgb.dtype
# Out:
# dtype('O')

# %%
y_xgb
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=object)

# %%
y_xgb = np.where(y_xgb, 'success', 'fail').tolist()
print(y_xgb)
# Out:
# ['fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'fail', 'fail', 'fail', 'success', 'fail', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'success', 'success', 'fail', 'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fai ...
